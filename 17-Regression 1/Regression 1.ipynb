# %% [markdown]
# # Regression Modeling, Part 1
#
# This lesson is adapted from a few sources:
#
# - The statsmodels tutorials: http://statsmodels.sourceforge.net/
# - General Assembly's Data Science Course: https://github.com/justmarkham/DAT4
# - Urban Informatics and Visualization Course: https://github.com/waddell/urban-informatics-and-visualization
#
#
# ### Motivation
#
# Why are we learning linear regression?
#
# It gives us a way to more formally understand the relationships between variables.  There are a few things in particular we may want to do:
#
# - inference: Identify whether the correlations are statistically significant. Of particular interest is the ability to control for confounding factors.
# - prediction: Change variables and predict the outcomes.
#
#
# ### Structure and Assumptions
#
# The statistical model is assumed to be $Y = X\beta + \epsilon$, where $\epsilon\sim N\left(0,\sigma^{2}\right)$
#
# We focus here on the simple Ordinary Least Squares (OLS) model that is the most widely used, but makes strong assumptions about the errors being indepentently and identically distributed (i.i.d.).  We won't get much into the theory/mathematics of these models.  There is plenty written about that, and it should have been covered in your stats classes.  Here, we will focus more on how to specify a good model.
#
# For now, there are a few things to keep in mind:
#
# 1. The response variable should be continuous.
# 2. The terms should be linear, but they can include non-linear transformations.
# 3. The residuals (or errors) should be random.
#
#
# ### Libraries
#
# Will be using [Statsmodels](http://statsmodels.sourceforge.net/).  Start with:
#
#     conda install statsmodels

# %% [markdown]
# ### Today's objective
#
# Today, we will be looking at wage and salary data to understand the factors that increase or decrease wages.  In particular, we are interested in knowing the effect of getting a degree in civil engineering!
#
# We'll be using the PUMS data.  The PUMS (Public-Use Microdata Sample) comes from the Census Bureau's American Community Survey (ACS).  Each record represents an individual person, rather than being aggregate tabulations as most Census tables are.  To protect the privacy of respondents, home locations are only known at very aggregate geographies (known as PUMAs).  You can find the data here:
#
# https://www.census.gov/programs-surveys/acs/data/pums.html
#
# I've downloaded the relevant table and documentation for you already.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.formula.api as smf

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# get the data
df = pd.read_csv('data/psam_p21.csv')
df.head()
# Out:
#   RT       SERIALNO  DIVISION  SPORDER  PUMA  REGION  ST   ADJINC  PWGTP  \
# 0  P  2013000000081         6        1   200       3  21  1061971     20
# 1  P  2013000000085         6        1  1703       3  21  1061971     14
# 2  P  2013000000085         6        2  1703       3  21  1061971     13
# 3  P  2013000000115         6        1  1701       3  21  1061971      8
# 4  P  2013000000211         6        1  1800       3  21  1061971      5
#
#    AGEP  ...  PWGTP71  PWGTP72  PWGTP73  PWGTP74  PWGTP75  PWGTP76  PWGTP77  \
# 0    81  ...       31       24       23       16       20       34       25
# 1    73  ...       14       25       23       15       14       13       15
# 2    71  ...       14       24       22       14       14       12       14
# 3    18  ...        8        8        8        1       15        1        7
# 4    34  ...        2        5        1        9        4        2        1
#
#    PWGTP78  PWGTP79  PWGTP80
# 0       23        6       18
# 1       22       13       13
# 2       20       13       14
# 3       15       14       14
# 4        3        5        4
#
# [5 rows x 286 columns]

# %%
# keep only the people who have worked within the last 12 months
'''
WKL 1
When last worked
b .N/A (less than 16 years old)
1 .Within the past 12 months
2 .1-5 years ago
3 .Over 5 years ago or never worked
'''

df = df[df['WKL']==1]
len(df)
# Out:
# 108512

# %% [markdown]
# ### Look at the data
#
# It is often a good idea to look at the data we want to model, and see how it relates to some variables we expect to be important.  We can do this using seaborn, which we learned about a few weeks ago.

# %%
'''
WAGP 6
Wages or salary income past 12 months
bbbbbb .N/A (less than 15 years old)
000000 .None
000001..999999 .$1 to 999999 (Rounded and top-coded)
'''

sns.distplot(df['WAGP'])
#log normal distribution

# %%
df['WAGP_LOG']=np.log(df['WAGP']+1)
sns.distplot(df['WAGP_LOG'])

# %%
# we may think that wages relate to hours worked, so let's look at that relationship
'''
WKHP 2
Usual hours worked per week past 12 months
bb .N/A (less than 16 years old/did not work during the past 12
.months)
01..98 .1 to 98 usual hours
99 .99 or more usual hours
'''

sns.jointplot(x="WKHP", y="WAGP", data=df, size=8)
# Out:
# C:\Users\moni_\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Notice how the data are lumpy.  It looks like people round when they report their values.

# %%
# we can also look at a regression plot, like we did before
sns.regplot(x="WKHP", y="WAGP", data=df)
#positive relation

# %% [markdown]
# ### Estimating a model
#
# OK, that's fine, we can do plots, but we want some actual numbers.  For this, we want to estimate what the model coefficients are.

# %%
# This is a basic model estimation in statsmodels
# the dependent variable is on the left side of the ~ 
#wages as a function of hours
mod = smf.ols(formula='WAGP ~ WKHP', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                 1.730e+04
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:10   Log-Likelihood:            -1.3144e+06
# No. Observations:              108512   AIC:                         2.629e+06
# Df Residuals:                  108510   BIC:                         2.629e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.381e+04    416.670    -33.140      0.000   -1.46e+04    -1.3e+04
# WKHP        1358.1901     10.327    131.519      0.000    1337.949    1378.431
# ==============================================================================
# Omnibus:                    96496.420   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3540601.757
# Skew:                           4.278   Prob(JB):                         0.00
# Kurtosis:                      29.643   Cond. No.                         126.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Notice a few things:
#
# 1. Goodness of fit measures
# 2. Model coefficients and t-statistics
# 3. The model and results objects

# %%
df2=df[:100]
mod = smf.ols(formula='WAGP ~ WKHP', data=df2)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.136
# Method:                 Least Squares   F-statistic:                     16.65
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):           9.18e-05
# Time:                        12:28:10   Log-Likelihood:                -1192.8
# No. Observations:                 100   AIC:                             2390.
# Df Residuals:                      98   BIC:                             2395.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -8154.8232   1.04e+04     -0.781      0.436   -2.89e+04    1.26e+04
# WKHP        1062.1324    260.327      4.080      0.000     545.522    1578.743
# ==============================================================================
# Omnibus:                      127.838   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3638.472
# Skew:                           4.289   Prob(JB):                         0.00
# Kurtosis:                      31.278   Cond. No.                         113.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# That's fine, but we may try some more things.  Perhaps age matters. 
# More experience -> higher wages? 
#wages as a function of hour and age

mod = smf.ols(formula='WAGP ~ WKHP + AGEP', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                 1.048e+04
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:10   Log-Likelihood:            -1.3129e+06
# No. Observations:              108512   AIC:                         2.626e+06
# Df Residuals:                  108509   BIC:                         2.626e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.277e+04    531.679    -61.626      0.000   -3.38e+04   -3.17e+04
# WKHP        1308.8372     10.218    128.091      0.000    1288.810    1328.864
# AGEP         489.9949      8.726     56.152      0.000     472.892     507.098
# ==============================================================================
# Omnibus:                    96311.275   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3569004.944
# Skew:                           4.260   Prob(JB):                         0.00
# Kurtosis:                      29.773   Cond. No.                         238.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Categorical variables
#
# We may also want to include categorical variables.  We can include them by calculating a 'dummy' variable, which is 1 if the value is in a category, and zero otherwise.

# %%
'''
SCHL 2
Educational attainment
bb .N/A (less than 3 years old)
01 .No schooling completed
02 .Nursery school, preschool 03 .Kindergarten
04 .Grade 1
05 .Grade 2
06 .Grade 3
07 .Grade 4
08 .Grade 5
09 .Grade 6
10 .Grade 7
11 .Grade 8
12 .Grade 9
13 .Grade 10
14 .Grade 11 15 .12th grade - no diploma
16 .Regular high school diploma
17 .GED or alternative credential
18 .Some college, but less than 1 year
19 .1 or more years of college credit, no degree
20 .Associate's degree
21 .Bachelor's degree
22 .Master's degree
23 .Professional degree beyond a bachelor's degree
24 .Doctorate degree
'''

# Is someone a college grad
df['college_grad'] = df['SCHL'].apply(lambda x : x>=20)
df['college_grad']
# Out:
# 4          True
# 5         False
# 11        False
# 12        False
# 13        False
# 14         True
# 15         True
# 16         True
# 18        False
# 20         True
# 21         True
# 22         True
# 26        False
# 28        False
# 29         True
# 30         True
# 31         True
# 32         True
# 33        False
# 39        False
# 40         True
# 41        False
# 43        False
# 45         True
# 48        False
# 49        False
# 50        False
# 53        False
# 54         True
# 57         True
#           ...
# 224461    False
# 224471    False
# 224475    False
# 224478    False
# 224485    False
# 224487    False
# 224488     True
# 224492    False
# 224497    False
# 224500    False
# 224501    False
# 224503    False
# 224505    False
# 224515    False
# 224519    False
# 224523    False
# 224528    False
# 224529    False
# 224530    False
# 224531    False
# 224532    False
# 224534    False
# 224538    False
# 224540    False
# 224546    False
# 224548    False
# 224552    False
# 224554    False
# 224557    False
# 224558    False
# Name: college_grad, Length: 108512, dtype: bool

# %%
# note that I can wrap long strings with a \ character
mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + college_grad", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.224
# Method:                 Least Squares   F-statistic:                 1.046e+04
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:10   Log-Likelihood:            -1.3087e+06
# No. Observations:              108512   AIC:                         2.617e+06
# Df Residuals:                  108508   BIC:                         2.617e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept            -3.553e+04    512.313    -69.361      0.000   -3.65e+04   -3.45e+04
# college_grad[T.True]  2.478e+04    264.887     93.548      0.000    2.43e+04    2.53e+04
# WKHP                  1212.8319      9.883    122.721      0.000    1193.462    1232.202
# AGEP                   422.9947      8.425     50.208      0.000     406.482     439.507
# ==============================================================================
# Omnibus:                    96545.724   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3739995.510
# Skew:                           4.257   Prob(JB):                         0.00
# Kurtosis:                      30.472   Cond. No.                         239.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Looks like a college degree is worth $23,000 per year...
#
# What happens if we include both college and non-college in the same model?

# %%
# not a college grad
df['not_college_grad'] = df['SCHL'].apply(lambda x : x<20)

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + college_grad \
                       + not_college_grad", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.224
# Method:                 Least Squares   F-statistic:                 1.046e+04
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:10   Log-Likelihood:            -1.3087e+06
# No. Observations:              108512   AIC:                         2.617e+06
# Df Residuals:                  108508   BIC:                         2.617e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                -1.543e+04    347.796    -44.365      0.000   -1.61e+04   -1.47e+04
# college_grad[T.True]      4674.8909    238.457     19.605      0.000    4207.518    5142.264
# not_college_grad[T.True]  -2.01e+04    196.727   -102.196      0.000   -2.05e+04   -1.97e+04
# WKHP                      1212.8319      9.883    122.721      0.000    1193.462    1232.202
# AGEP                       422.9947      8.425     50.208      0.000     406.482     439.507
# ==============================================================================
# Omnibus:                    96545.724   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3739995.510
# Skew:                           4.257   Prob(JB):                         0.00
# Kurtosis:                      30.472   Cond. No.                     6.13e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.01e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# We get a warning, and very different results for that term.  This is an over-specified model, and the method cannot estimate the correct coefficients.  To avoid this, we always need to make sure that categorical variables leave one out.  This one that gets left out is known as the reference variable.

# %%
# We can do all categories, minus one, for a variable by including it in a C() command

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + C(SCHL)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     1566.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:11   Log-Likelihood:            -1.3057e+06
# No. Observations:              108512   AIC:                         2.612e+06
# Df Residuals:                  108486   BIC:                         2.612e+06
# Df Model:                          25
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept       -3.918e+04   1729.679    -22.649      0.000   -4.26e+04   -3.58e+04
# C(SCHL)[T.2.0]  -6414.4022   1.06e+04     -0.603      0.547   -2.73e+04    1.44e+04
# C(SCHL)[T.3.0]   4573.4376   1.55e+04      0.295      0.768   -2.58e+04    3.49e+04
# C(SCHL)[T.4.0]  -1215.6107   1.37e+04     -0.089      0.929    -2.8e+04    2.56e+04
# C(SCHL)[T.5.0]   1509.7699   8649.166      0.175      0.861   -1.54e+04    1.85e+04
# C(SCHL)[T.6.0]  -1.009e+04   7384.835     -1.367      0.172   -2.46e+04    4380.730
# C(SCHL)[T.7.0]   -645.6514   7078.005     -0.091      0.927   -1.45e+04    1.32e+04
# C(SCHL)[T.8.0]  -1877.9535   5640.476     -0.333      0.739   -1.29e+04    9177.300
# C(SCHL)[T.9.0]  -5466.7922   3404.775     -1.606      0.108   -1.21e+04    1206.518
# C(SCHL)[T.10.0] -2960.1139   3377.755     -0.876      0.381   -9580.466    3660.238
# C(SCHL)[T.11.0] -3820.5604   2080.542     -1.836      0.066   -7898.393     257.272
# C(SCHL)[T.12.0]   780.7842   2030.774      0.384      0.701   -3199.504    4761.072
# C(SCHL)[T.13.0]  3067.7709   1884.747      1.628      0.104    -626.306    6761.848
# C(SCHL)[T.14.0]  5750.2165   1822.571      3.155      0.002    2178.003    9322.430
# C(SCHL)[T.15.0]  3434.0905   2023.799      1.697      0.090    -532.527    7400.708
# C(SCHL)[T.16.0]  5051.5325   1670.491      3.024      0.002    1777.393    8325.672
# C(SCHL)[T.17.0]  1756.6932   1736.693      1.012      0.312   -1647.200    5160.586
# C(SCHL)[T.18.0]  7769.2208   1709.750      4.544      0.000    4418.135    1.11e+04
# C(SCHL)[T.19.0]  9594.1462   1680.348      5.710      0.000    6300.687    1.29e+04
# C(SCHL)[T.20.0]  1.375e+04   1703.054      8.073      0.000    1.04e+04    1.71e+04
# C(SCHL)[T.21.0]  2.995e+04   1679.050     17.840      0.000    2.67e+04    3.32e+04
# C(SCHL)[T.22.0]  3.384e+04   1706.461     19.829      0.000    3.05e+04    3.72e+04
# C(SCHL)[T.23.0]  7.747e+04   1839.258     42.119      0.000    7.39e+04    8.11e+04
# C(SCHL)[T.24.0]  5.758e+04   1989.561     28.943      0.000    5.37e+04    6.15e+04
# WKHP             1176.0524      9.712    121.090      0.000    1157.017    1195.088
# AGEP              400.8713      8.343     48.050      0.000     384.520     417.223
# ==============================================================================
# Omnibus:                    92668.381   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3444750.873
# Skew:                           3.997   Prob(JB):                         0.00
# Kurtosis:                      29.419   Cond. No.                     7.42e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# many of these are not significant, so let's drop some
def recode_school(schl): 
    if schl<=15: 
        return '15-No HS diploma'
    elif schl==16 or schl==17: 
        return '16-HS or GED'
    elif schl==18 or schl==19: 
        return '18-Some college'
    elif schl==20: 
        return '20-Associates degree'
    elif schl==21: 
        return '21-Bachelors degree'
    elif schl==22: 
        return '22-Masters degree'
    elif schl==23: 
        return '23-Prof grad degree'
    elif schl==24: 
        return '24-Doctorate degree'
    else: 
        return str(schl)

df['SCHL2'] = df['SCHL'].apply(recode_school)
df['SCHL2'].value_counts()
# Out:
# 16-HS or GED            31988
# 18-Some college         26338
# 21-Bachelors degree     18203
# 20-Associates degree     9593
# 15-No HS diploma         9515
# 22-Masters degree        8984
# 23-Prof grad degree      2541
# 24-Doctorate degree      1350
# Name: SCHL2, dtype: int64

# %%
# We can do all categories, minus one, for a variable by including it in a C() command

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + C(SCHL2)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     4334.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:12   Log-Likelihood:            -1.3058e+06
# No. Observations:              108512   AIC:                         2.612e+06
# Df Residuals:                  108502   BIC:                         2.612e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -3.639e+04    606.336    -60.011      0.000   -3.76e+04   -3.52e+04
# C(SCHL2)[T.16-HS or GED]          2226.3250    479.854      4.640      0.000    1285.818    3166.832
# C(SCHL2)[T.18-Some college]       6724.7556    488.854     13.756      0.000    5766.609    7682.902
# C(SCHL2)[T.20-Associates degree]  1.151e+04    592.902     19.416      0.000    1.03e+04    1.27e+04
# C(SCHL2)[T.21-Bachelors degree]   2.772e+04    520.505     53.254      0.000    2.67e+04    2.87e+04
# C(SCHL2)[T.22-Masters degree]     3.163e+04    605.930     52.207      0.000    3.04e+04    3.28e+04
# C(SCHL2)[T.23-Prof grad degree]    7.53e+04    918.364     81.996      0.000    7.35e+04    7.71e+04
# C(SCHL2)[T.24-Doctorate degree]   5.542e+04   1191.356     46.518      0.000    5.31e+04    5.78e+04
# WKHP                              1171.9447      9.691    120.928      0.000    1152.950    1190.939
# AGEP                               391.8270      8.281     47.317      0.000     375.597     408.057
# ==============================================================================
# Omnibus:                    92644.699   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3437897.055
# Skew:                           3.997   Prob(JB):                         0.00
# Kurtosis:                      29.391   Cond. No.                         657.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['PUMA'].head()
# Out:
# 4     1800
# 5     1800
# 11     300
# 12     300
# 13     400
# Name: PUMA, dtype: int64

# %%
# add sex 
'''
SEX 1
Sex
1 .Male
2 .Female
'''

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + C(SCHL2) \
                       + C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     4129.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:13   Log-Likelihood:            -1.3050e+06
# No. Observations:              108512   AIC:                         2.610e+06
# Df Residuals:                  108501   BIC:                         2.610e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -2.959e+04    624.062    -47.417      0.000   -3.08e+04   -2.84e+04
# C(SCHL2)[T.16-HS or GED]          3096.9355    476.648      6.497      0.000    2162.713    4031.158
# C(SCHL2)[T.18-Some college]       8333.6728    486.687     17.123      0.000    7379.772    9287.573
# C(SCHL2)[T.20-Associates degree]  1.437e+04    592.453     24.248      0.000    1.32e+04    1.55e+04
# C(SCHL2)[T.21-Bachelors degree]   2.965e+04    518.648     57.164      0.000    2.86e+04    3.07e+04
# C(SCHL2)[T.22-Masters degree]     3.457e+04    605.527     57.091      0.000    3.34e+04    3.58e+04
# C(SCHL2)[T.23-Prof grad degree]    7.68e+04    912.055     84.207      0.000     7.5e+04    7.86e+04
# C(SCHL2)[T.24-Doctorate degree]   5.691e+04   1182.783     48.119      0.000    5.46e+04    5.92e+04
# C(SEX)[T.2]                      -1.044e+04    254.367    -41.037      0.000   -1.09e+04   -9940.029
# WKHP                              1082.4172      9.861    109.764      0.000    1063.089    1101.745
# AGEP                               394.0891      8.218     47.957      0.000     377.983     410.195
# ==============================================================================
# Omnibus:                    92146.743   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3421922.029
# Skew:                           3.961   Prob(JB):                         0.00
# Kurtosis:                      29.345   Cond. No.                         658.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['SEX'].value_counts()
# Out:
# 1    56623
# 2    51889
# Name: SEX, dtype: int64

# %%
mod = smf.ols(formula="WAGP \
                       ~ WKHP\
                       +C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     9071.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:13   Log-Likelihood:            -1.3141e+06
# No. Observations:              108512   AIC:                         2.628e+06
# Df Residuals:                  108509   BIC:                         2.628e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -8044.9570    466.890    -17.231      0.000   -8960.054   -7129.860
# C(SEX)[T.2] -7374.1779    273.008    -27.011      0.000   -7909.270   -6839.086
# WKHP         1299.6354     10.518    123.560      0.000    1279.020    1320.251
# ==============================================================================
# Omnibus:                    96019.390   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3492883.439
# Skew:                           4.247   Prob(JB):                         0.00
# Kurtosis:                      29.465   Cond. No.                         148.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Confounding factors
#
# It looks like there is a $11,000 penalty for being a woman.  Why is that?
#
# First, we want to make sure that we are measuring the effect of sex, and not the effect of something else that sex is correlated with.  For example, maybe we suspect that women earn less because they tend to work fewer hours or are younger.  Let's start by looking at the data categorically...

# %%
# look at the average values
#confounding means skwing result
df[['SEX', 'WAGP', 'WKHP', 'AGEP']].groupby('SEX').mean()
# Out:
#              WAGP       WKHP       AGEP
# SEX
# 1    44935.999117  40.766014  42.588153
# 2    30609.459423  35.416543  42.478695

# %% [markdown]
# Yes, this is true for hours worked at least, but it is not the whole story.  The total wage gap is $15,000.  That is made up of several components.
#
# Sometimes it is useful to look at pair-plots to see the relationships.

# %%
# for a select set of variables
sns.pairplot(df[['SEX', 'WAGP', 'WKHP', 'AGEP']])

# %%
# if we were to leave out the hours worked, we would get a different coefficient on sex

mod = smf.ols(formula="WAGP \
                       ~ AGEP \
                       + C(SCHL2) \
                       + C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     2925.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:33   Log-Likelihood:            -1.3107e+06
# No. Observations:              108512   AIC:                         2.621e+06
# Df Residuals:                  108502   BIC:                         2.621e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                         6065.9441    561.651     10.800      0.000    4965.116    7166.772
# C(SCHL2)[T.16-HS or GED]          9001.9893    499.202     18.033      0.000    8023.560    9980.419
# C(SCHL2)[T.18-Some college]       1.353e+04    510.563     26.499      0.000    1.25e+04    1.45e+04
# C(SCHL2)[T.20-Associates degree]  2.193e+04    620.240     35.357      0.000    2.07e+04    2.31e+04
# C(SCHL2)[T.21-Bachelors degree]   3.783e+04    541.013     69.918      0.000    3.68e+04    3.89e+04
# C(SCHL2)[T.22-Masters degree]     4.348e+04    632.496     68.745      0.000    4.22e+04    4.47e+04
# C(SCHL2)[T.23-Prof grad degree]   8.781e+04    955.523     91.901      0.000    8.59e+04    8.97e+04
# C(SCHL2)[T.24-Doctorate degree]   6.778e+04   1242.345     54.558      0.000    6.53e+04    7.02e+04
# C(SEX)[T.2]                      -1.662e+04    261.473    -63.545      0.000   -1.71e+04   -1.61e+04
# AGEP                               452.4042      8.644     52.339      0.000     435.463     469.346
# ==============================================================================
# Omnibus:                    86860.400   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2673047.686
# Skew:                           3.679   Prob(JB):                         0.00
# Kurtosis:                      26.175   Cond. No.                         501.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# For this reason, regression provides an important tool to test the net effects of different factors.  If we wanted, we could also interact sex with the type of degree.

# %%
# we can also interact terms

df['AGE_WOMEN'] = df['AGEP'] * (df['SEX'] - 1)
df['AGE_MEN']   = df['AGEP'] * (2-df['SEX'])

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGE_MEN \
                       + AGE_WOMEN \
                       + C(SCHL2) \
                       + C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     3783.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:34   Log-Likelihood:            -1.3048e+06
# No. Observations:              108512   AIC:                         2.610e+06
# Df Residuals:                  108500   BIC:                         2.610e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -3.466e+04    706.962    -49.020      0.000    -3.6e+04   -3.33e+04
# C(SCHL2)[T.16-HS or GED]          3271.3805    476.282      6.869      0.000    2337.874    4204.887
# C(SCHL2)[T.18-Some college]       8330.9446    486.173     17.136      0.000    7378.052    9283.837
# C(SCHL2)[T.20-Associates degree]  1.447e+04    591.865     24.444      0.000    1.33e+04    1.56e+04
# C(SCHL2)[T.21-Bachelors degree]   2.951e+04    518.185     56.940      0.000    2.85e+04    3.05e+04
# C(SCHL2)[T.22-Masters degree]     3.463e+04    604.898     57.244      0.000    3.34e+04    3.58e+04
# C(SCHL2)[T.23-Prof grad degree]   7.641e+04    911.460     83.830      0.000    7.46e+04    7.82e+04
# C(SCHL2)[T.24-Doctorate degree]   5.661e+04   1181.699     47.909      0.000    5.43e+04    5.89e+04
# C(SEX)[T.2]                         44.6245    735.441      0.061      0.952   -1396.829    1486.078
# WKHP                              1083.5581      9.851    109.993      0.000    1064.250    1102.866
# AGE_MEN                            511.1935     11.261     45.393      0.000     489.121     533.266
# AGE_WOMEN                          265.0055     11.815     22.429      0.000     241.848     288.163
# ==============================================================================
# Omnibus:                    91939.951   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3412249.796
# Skew:                           3.947   Prob(JB):                         0.00
# Kurtosis:                      29.313   Cond. No.                         561.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# we can get the same thing, with a slightly different specification
# this tells us whether the AGEP and AGE_WOMEN coefficients are significantly different from each other

mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       + AGEP \
                       + AGE_WOMEN \
                       + C(SCHL2) \
                       + C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     3783.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:35   Log-Likelihood:            -1.3048e+06
# No. Observations:              108512   AIC:                         2.610e+06
# Df Residuals:                  108500   BIC:                         2.610e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -3.466e+04    706.962    -49.020      0.000    -3.6e+04   -3.33e+04
# C(SCHL2)[T.16-HS or GED]          3271.3805    476.282      6.869      0.000    2337.874    4204.887
# C(SCHL2)[T.18-Some college]       8330.9446    486.173     17.136      0.000    7378.052    9283.837
# C(SCHL2)[T.20-Associates degree]  1.447e+04    591.865     24.444      0.000    1.33e+04    1.56e+04
# C(SCHL2)[T.21-Bachelors degree]   2.951e+04    518.185     56.940      0.000    2.85e+04    3.05e+04
# C(SCHL2)[T.22-Masters degree]     3.463e+04    604.898     57.244      0.000    3.34e+04    3.58e+04
# C(SCHL2)[T.23-Prof grad degree]   7.641e+04    911.460     83.830      0.000    7.46e+04    7.82e+04
# C(SCHL2)[T.24-Doctorate degree]   5.661e+04   1181.699     47.909      0.000    5.43e+04    5.89e+04
# C(SEX)[T.2]                         44.6245    735.441      0.061      0.952   -1396.829    1486.078
# WKHP                              1083.5581      9.851    109.993      0.000    1064.250    1102.866
# AGEP                               511.1935     11.261     45.393      0.000     489.121     533.266
# AGE_WOMEN                         -246.1880     16.208    -15.190      0.000    -277.954    -214.421
# ==============================================================================
# Omnibus:                    91939.951   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3412249.796
# Skew:                           3.947   Prob(JB):                         0.00
# Kurtosis:                      29.313   Cond. No.                         703.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Homework
#
# 1. Calculate the value of a Civil Engineering degree and a degree in Transportation Sciences And Technologies, relative to a college degree in general.
#
# 2. Calculate the value of working in Architectural, Engineering, And Related Services versus wroking in transportation (anything starting in TRN).
#
# 3. Calculate the wage difference between male and female civil engineers
#
# 4. Use these data to determine what you should expect your starting salary to be for a full-time job in your career of choice after you graduate.  These may be a useful observation point for negotiations.  Who can come up with the highest (defensible) value?  What other data could you use to make your case?

# %% [markdown]
# # Answer 1

# %%
#2406 Civil Engineering
#5901 Transportation Sciences And Technologies
df['civil_eng'] = df['FOD1P'] == 2406
df['civil_eng'].value_counts()
# Out:
# False    108238
# True        274
# Name: civil_eng, dtype: int64

# %%
df['transport_science'] = df['FOD1P'] == 5901
df['transport_science'].value_counts()
# Out:
# False    108433
# True         79
# Name: transport_science, dtype: int64

# %%
mod = smf.ols(formula="WAGP \
                       ~ WKHP \
                       +civil_eng \
                       +transport_science\
                       + college_grad\
                       +AGEP", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.225
# Model:                            OLS   Adj. R-squared:                  0.225
# Method:                 Least Squares   F-statistic:                     6316.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:46:45   Log-Likelihood:            -1.3086e+06
# No. Observations:              108512   AIC:                         2.617e+06
# Df Residuals:                  108506   BIC:                         2.617e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -3.546e+04    512.007    -69.262      0.000   -3.65e+04   -3.45e+04
# civil_eng[T.True]          2.294e+04   2533.845      9.053      0.000     1.8e+04    2.79e+04
# transport_science[T.True]  3.805e+04   4707.326      8.083      0.000    2.88e+04    4.73e+04
# college_grad[T.True]       2.456e+04    265.386     92.533      0.000     2.4e+04    2.51e+04
# WKHP                       1211.1595      9.877    122.622      0.000    1191.800    1230.519
# AGEP                        422.7606      8.419     50.214      0.000     406.259     439.262
# ==============================================================================
# Omnibus:                    96591.677   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3751187.545
# Skew:                           4.260   Prob(JB):                         0.00
# Kurtosis:                      30.515   Cond. No.                     2.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Answer 2

# %%
#Calculate the value of working in Architectural, 
#Engineering, And Related Services versus wroking in transportation (anything starting in TRN).
'''
INDP
7290 .PRF-Architectural, Engineering, And Related Services
6070 .TRN-Air Transportation
6080 .TRN-Rail Transportation
6090 .TRN-Water Transportation
6170 .TRN-Truck Transportation
6180 .TRN-Bus Service And Urban Transit
6190 .TRN-Taxi And Limousine Service
6270 .TRN-Pipeline Transportation
6280 .TRN-Scenic And Sightseeing Transportation
6290 .TRN-Services Incidental To Transportation
6370 .TRN-Postal Service
6380 .TRN-Couriers And Messengers
6390 .TRN-Warehousing And Storage
'''
# Out:
# '\nINDP\n7290 .PRF-Architectural, Engineering, And Related Services\n6070 .TRN-Air Transportation\n6080 .TRN-Rail Transportation\n6090 .TRN-Water Transportation\n6170 .TRN-Truck Transportation\n6180 .TRN-Bus Service And Urban Transit\n6190 .TRN-Taxi And Limousine Service\n6270 .TRN-Pipeline Transportation\n6280 .TRN-Scenic And Sightseeing Transportation\n6290 .TRN-Services Incidental To Transportation\n6370 .TRN-Postal Service\n6380 .TRN-Couriers And Messengers\n6390 .TRN-Warehousing And Storage\n'

# %%
df['archi_engr'] = df['INDP'] == 7290
df['air_transport'] = df['INDP'] == 6070
df['rail_transport'] = df['INDP'] == 6080
df['water_transport'] = df['INDP'] == 6090
df['truck_transport'] = df['INDP'] == 6170
df['bus_transport'] = df['INDP'] == 6180
df['taxi_transport'] = df['INDP'] == 6190
df['pipe_transport'] = df['INDP'] == 6270
df['scene_transport'] = df['INDP'] == 6280
df['service_transport'] = df['INDP'] == 6290
df['postal_transport'] = df['INDP'] == 6370
df['courier_transport'] = df['INDP'] == 6380
df['ware_transport'] = df['INDP'] == 6390

# %%
mod = smf.ols(formula="WAGP \
                      ~ WKHP\
                       +air_transport \
                       +rail_transport \
                       +water_transport \
                       +truck_transport\
                       +bus_transport\
                       +taxi_transport\
                       +pipe_transport \
                       +scene_transport\
                       +service_transport\
                       + postal_transport \
                       +courier_transport \
                       + ware_transport\
                       +archi_engr \
                             ", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     1275.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:35   Log-Likelihood:            -1.3142e+06
# No. Observations:              108512   AIC:                         2.628e+06
# Df Residuals:                  108497   BIC:                         2.629e+06
# Df Model:                          14
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.417e+04    417.275    -33.963      0.000    -1.5e+04   -1.34e+04
# air_transport[T.True]      2.497e+04   2957.138      8.445      0.000    1.92e+04    3.08e+04
# rail_transport[T.True]     1.345e+04   2799.589      4.803      0.000    7959.006    1.89e+04
# water_transport[T.True]    6984.6162   4260.175      1.640      0.101   -1365.266    1.53e+04
# truck_transport[T.True]   -1.319e+04   1169.203    -11.280      0.000   -1.55e+04   -1.09e+04
# bus_transport[T.True]     -7127.8567   3408.452     -2.091      0.037   -1.38e+04    -447.339
# taxi_transport[T.True]    -1.918e+04   4565.809     -4.201      0.000   -2.81e+04   -1.02e+04
# pipe_transport[T.True]     3.692e+04   6421.831      5.749      0.000    2.43e+04    4.95e+04
# scene_transport[T.True]   -1.268e+04   8985.444     -1.412      0.158   -3.03e+04    4926.945
# service_transport[T.True] -2760.8051   2028.961     -1.361      0.174   -6737.539    1215.929
# postal_transport[T.True]   4613.2564   1951.761      2.364      0.018     787.833    8438.680
# courier_transport[T.True]  1.176e+04   1299.688      9.049      0.000    9213.575    1.43e+04
# ware_transport[T.True]    -8536.7480   1991.039     -4.288      0.000   -1.24e+04   -4634.340
# archi_engr[T.True]         1.599e+04   1686.163      9.483      0.000    1.27e+04    1.93e+04
# WKHP                       1365.1859     10.367    131.684      0.000    1344.866    1385.505
# ==============================================================================
# Omnibus:                    96722.921   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3578911.447
# Skew:                           4.291   Prob(JB):                         0.00
# Kurtosis:                      29.794   Cond. No.                     2.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Answer 3

# %%
#Calculate the wage difference between male and female civil engineers
mod = smf.ols(formula="WAGP \
                       ~ WKHP\
                       +civil_eng \
                       +  C(SEX) \
                             ", 
              data=df)
res = mod.fit()
print(res.summary())
#The wage difference for being female civil engineer is 7248.0652
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     6120.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        12:28:35   Log-Likelihood:            -1.3140e+06
# No. Observations:              108512   AIC:                         2.628e+06
# Df Residuals:                  108508   BIC:                         2.628e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -8130.3317    466.533    -17.427      0.000   -9044.730   -7215.933
# civil_eng[T.True]   3.63e+04   2658.765     13.653      0.000    3.11e+04    4.15e+04
# C(SEX)[T.2]       -7248.0652    272.932    -26.556      0.000   -7783.007   -6713.123
# WKHP               1297.8926     10.510    123.490      0.000    1277.293    1318.492
# ==============================================================================
# Omnibus:                    96093.391   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3508026.803
# Skew:                           4.251   Prob(JB):                         0.00
# Kurtosis:                      29.525   Cond. No.                         805.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Answer 4

# %%
#2102 .Computer Science
df['computer_science'] = df['FOD1P'] == 2102
mod = smf.ols(formula="WAGP \
                        ~WKHP\
                        +AGE_WOMEN \
                       +computer_science \
                       + C(SCHL2) \
                       + C(SEX)", 
              data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGP   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     3537.
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):               0.00
# Time:                        14:06:29   Log-Likelihood:            -1.3058e+06
# No. Observations:              108512   AIC:                         2.612e+06
# Df Residuals:                  108500   BIC:                         2.612e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                        -1.441e+04    552.983    -26.052      0.000   -1.55e+04   -1.33e+04
# computer_science[T.True]          1.782e+04   2096.061      8.500      0.000    1.37e+04    2.19e+04
# C(SCHL2)[T.16-HS or GED]          4042.3925    480.317      8.416      0.000    3100.978    4983.807
# C(SCHL2)[T.18-Some college]       8329.2101    490.605     16.977      0.000    7367.630    9290.790
# C(SCHL2)[T.20-Associates degree]  1.521e+04    597.022     25.484      0.000     1.4e+04    1.64e+04
# C(SCHL2)[T.21-Bachelors degree]   3.039e+04    523.436     58.051      0.000    2.94e+04    3.14e+04
# C(SCHL2)[T.22-Masters degree]     3.613e+04    609.610     59.262      0.000    3.49e+04    3.73e+04
# C(SCHL2)[T.23-Prof grad degree]   7.969e+04    916.806     86.921      0.000    7.79e+04    8.15e+04
# C(SCHL2)[T.24-Doctorate degree]   5.974e+04   1190.404     50.181      0.000    5.74e+04    6.21e+04
# C(SEX)[T.2]                      -2.125e+04    569.901    -37.287      0.000   -2.24e+04   -2.01e+04
# WKHP                              1102.1548      9.932    110.968      0.000    1082.688    1121.622
# AGE_WOMEN                          257.1202     11.922     21.567      0.000     233.753     280.487
# ==============================================================================
# Omnibus:                    92495.372   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3419456.090
# Skew:                           3.988   Prob(JB):                         0.00
# Kurtosis:                      29.319   Cond. No.                         777.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# For a 27 years old computer science female PhD student, value of WAGP is almost 92K.
# This seems reasonable and I can expect it as my starting salary.

# %% [markdown]
# ### Bonus
#
# Win your bracket next year with a data-driven March Madness!
#
# https://canvas.harvard.edu/courses/12656/files/2822157/download?verifier...1
